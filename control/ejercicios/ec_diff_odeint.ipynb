# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt


# Initialization
tstart = 0
tstop = 25
increment = 1

x0 = 1
t = np.linspace(tstart, tstop, N)

# function that returns dx/dt


def mydiff(x,t):
    T = 5
    a = -1/T
    dxdt = a*x
    return dxdt



# solve ODE
print(mydiff)
x = odeint(mydiff, x0, t)


# plot
plt.plot(t,x)
plt.title('Plot Diferencial Equation')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()
plt.axis([0,25,0,1])
plt.show()
# Out:
# <function mydiff at 0x7f8884efc280>

# %%
import scipy.integrate import odeint
# Out:
#   File "/var/folders/xq/g20qj_6j4ggfpf14kcdtjcbr0000gn/T/ipykernel_26946/601559085.py", line 1
#     import scipy.integrate import odeint
#                            ^
# SyntaxError: invalid syntax
